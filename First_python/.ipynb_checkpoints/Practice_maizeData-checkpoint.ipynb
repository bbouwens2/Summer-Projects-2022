# %%
import pandas as pd

# %%
data = pd.read_csv('Maize_2020.csv')

# %%
data.head(10)
# Out:
#    Unnamed: 0   crop  PlotID  year trt pheno      CHL       EWT       LWC  \
# 0        1269  maize    1001  2020  HN   yes  456.800  0.016142  0.728814
# 1        1270  maize    1002  2020  HN   yes  268.475  0.015019  0.705036
# 2        1271  maize    1003  2020  HN   yes  391.975  0.016189  0.767030
# 3        1272  maize    1004  2020  HN   yes  488.650  0.016668  0.780142
# 4        1273  maize    1005  2020  HN   yes  429.325  0.015147  0.719752
# 5        1274  maize    1006  2020  HN   yes  388.900  0.011394  0.710443
# 6        1275  maize    1007  2020  HN   yes  444.800  0.016667  0.773681
# 7        1276  maize    1008  2020  HN   yes  457.700  0.016072  0.712171
# 8        1277  maize    1009  2020  HN   yes  474.100  0.017464  0.724556
# 9        1278  maize    1010  2020  HN   yes  370.550  0.016753  0.750842
#
#           SLA  ...     X2491     X2492     X2493     X2494     X2495  \
# 0  166.488281  ...  0.076210  0.076144  0.075867  0.075773  0.075515
# 1  159.146341  ...  0.083926  0.083274  0.082861  0.082943  0.082536
# 2  203.368421  ...  0.062543  0.061958  0.061579  0.061323  0.061225
# 3  212.887097  ...  0.077193  0.076936  0.076582  0.076728  0.076516
# 4  169.557196  ...  0.070101  0.069837  0.069617  0.069944  0.069658
# 5  215.344262  ...  0.088581  0.088296  0.087942  0.087314  0.086973
# 6  205.112782  ...  0.059799  0.059354  0.059076  0.059167  0.058923
# 7  153.953143  ...  0.073378  0.073263  0.072957  0.072511  0.072198
# 8  150.624407  ...  0.072202  0.071749  0.071407  0.070815  0.070398
# 9  179.873874  ...  0.070611  0.070861  0.070575  0.070417  0.070218
#
#       X2496     X2497     X2498     X2499     X2500
# 0  0.074958  0.074545  0.074182  0.073884  0.073802
# 1  0.081516  0.081260  0.081504  0.081208  0.081202
# 2  0.061467  0.061353  0.061195  0.061081  0.060759
# 3  0.075703  0.075252  0.074950  0.074795  0.074900
# 4  0.068802  0.068408  0.067899  0.067480  0.067600
# 5  0.086866  0.086534  0.086168  0.085974  0.085730
# 6  0.058360  0.058189  0.058310  0.057941  0.057570
# 7  0.071876  0.071532  0.071276  0.070935  0.070376
# 8  0.070249  0.070080  0.070078  0.069659  0.068928
# 9  0.069431  0.069117  0.069540  0.069282  0.068586
#
# [10 rows x 2172 columns]

# %%
data.CHL
# Out:
# 0       456.800
# 1       268.475
# 2       391.975
# 3       488.650
# 4       429.325
#          ...
# 1653        NaN
# 1654        NaN
# 1655    401.250
# 1656        NaN
# 1657        NaN
# Name: CHL, Length: 1658, dtype: float64

# %%
data.head()
# Out:
#    Unnamed: 0   crop  PlotID  year trt pheno      CHL       EWT       LWC  \
# 0        1269  maize    1001  2020  HN   yes  456.800  0.016142  0.728814
# 1        1270  maize    1002  2020  HN   yes  268.475  0.015019  0.705036
# 2        1271  maize    1003  2020  HN   yes  391.975  0.016189  0.767030
# 3        1272  maize    1004  2020  HN   yes  488.650  0.016668  0.780142
# 4        1273  maize    1005  2020  HN   yes  429.325  0.015147  0.719752
#
#           SLA  ...     X2491     X2492     X2493     X2494     X2495  \
# 0  166.488281  ...  0.076210  0.076144  0.075867  0.075773  0.075515
# 1  159.146341  ...  0.083926  0.083274  0.082861  0.082943  0.082536
# 2  203.368421  ...  0.062543  0.061958  0.061579  0.061323  0.061225
# 3  212.887097  ...  0.077193  0.076936  0.076582  0.076728  0.076516
# 4  169.557196  ...  0.070101  0.069837  0.069617  0.069944  0.069658
#
#       X2496     X2497     X2498     X2499     X2500
# 0  0.074958  0.074545  0.074182  0.073884  0.073802
# 1  0.081516  0.081260  0.081504  0.081208  0.081202
# 2  0.061467  0.061353  0.061195  0.061081  0.060759
# 3  0.075703  0.075252  0.074950  0.074795  0.074900
# 4  0.068802  0.068408  0.067899  0.067480  0.067600
#
# [5 rows x 2172 columns]

# %%
data.shape
# Out:
# (1658, 2172)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.groupby('crop').mean()
# Out:
#        Unnamed: 0       PlotID    year         CHL       EWT     LWC  \
# crop
# maize      2097.5  1917.941496  2020.0  458.827586  0.017728  0.7622
#
#               SLA         N         P         K  ...     X2491     X2492  \
# crop                                             ...
# maize  186.161189  3.006648  0.232789  2.226883  ...  0.047481  0.047253
#
#           X2493     X2494     X2495     X2496     X2497     X2498     X2499  \
# crop
# maize  0.047033  0.046824  0.046614  0.046422  0.046215  0.045991  0.045791
#
#           X2500
# crop
# maize  0.045591
#
# [1 rows x 2169 columns]

# %%
data[data.SLA=='1001'].PlotID.count()
# Out:
# 0

# %%
# %matplotlib inline

# %%
data.CHL.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.CHL.plot(kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 data.CHL.plot(kind='scatter')
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py:919, in PlotAccessor.__call__(self, *args, **kwargs)
#     917         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918     else:
# --> 919         raise ValueError(f"plot kind {kind} can only be used for data frames")
#     920 elif kind in self._series_kinds:
#     921     if isinstance(data, ABCDataFrame):
#
# ValueError: plot kind scatter can only be used for data frames

# %%
data.loc[23, 'CHL']
# Out:
# 350.65

# %%
data.memory_usage(deep=True)
# Out:
# Index            128
# Unnamed: 0     13264
# crop          102796
# PlotID         13264
# year           13264
#                ...
# X2496          13264
# X2497          13264
# X2498          13264
# X2499          13264
# X2500          13264
# Length: 2173, dtype: int64

# %%
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1658 entries, 0 to 1657
# Columns: 2172 entries, Unnamed: 0 to X2500
# dtypes: float64(2166), int64(3), object(3)
# memory usage: 27.7 MB

# %%
data.memory_usage(deep=True).sum()
# Out:
# 29068431
