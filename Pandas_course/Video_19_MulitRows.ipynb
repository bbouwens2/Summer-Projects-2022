# %%
import pandas as pd

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head(3)
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[0, :]
# Out:
# City                       Ithaca
# Colors Reported               NaN
# Shape Reported           TRIANGLE
# State                          NY
# Time               6/1/1930 22:00
# Name: 0, dtype: object

# %%
ufo.loc[[0,1,2], :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[0:2,['City', 'State']]
# Out:
#           City State
# 0       Ithaca    NY
# 1  Willingboro    NJ
# 2      Holyoke    CO

# %%
ufo.head(3).drop('Time', axis=1)
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO

# %%
ufo[ufo.State=='IN']
# Out:
#              City Colors Reported Shape Reported State              Time
# 91         Scipio             RED         SPHERE    IN   5/10/1948 19:00
# 181     Fortville             NaN           DISK    IN    6/13/1952 7:30
# 244        Dublin             NaN           CONE    IN   7/17/1953 22:00
# 256     Pendleton           GREEN           DISK    IN  11/21/1953 22:30
# 292       Morroco             NaN        VARIOUS    IN   7/12/1954 17:30
# ...           ...             ...            ...   ...               ...
# 17949      Kokomo          ORANGE          FLASH    IN  11/15/2000 20:00
# 18057  South Bend             NaN          LIGHT    IN   12/1/2000 19:20
# 18067  Fort Wayne             NaN          OTHER    IN   12/3/2000 19:10
# 18085   Thorntown             NaN            NaN    IN    12/6/2000 4:00
# 18182  Evansville             NaN       FIREBALL    IN  12/24/2000 20:00
#
# [326 rows x 5 columns]

# %%
ufo.loc[ufo.City=='Oakland', :]
# Out:
#           City Colors Reported Shape Reported State              Time
# 1694   Oakland             NaN          CIGAR    CA   7/21/1968 14:00
# 2144   Oakland             NaN           DISK    CA    8/19/1971 0:00
# 4686   Oakland             NaN          LIGHT    MD     6/1/1982 0:00
# 7293   Oakland             NaN          LIGHT    CA   3/28/1994 17:00
# 8488   Oakland             NaN            NaN    CA   8/10/1995 21:45
# 8768   Oakland             NaN            NaN    CA  10/10/1995 22:40
# 10816  Oakland             NaN          LIGHT    OR   10/1/1997 21:30
# 10948  Oakland             NaN           DISK    CA  11/14/1997 19:55
# 11045  Oakland             NaN       TRIANGLE    CA   12/10/1997 1:30
# 12322  Oakland             NaN       FIREBALL    CA   10/9/1998 19:40
# 12941  Oakland             NaN       CYLINDER    CA   1/23/1999 21:30
# 16803  Oakland             NaN       TRIANGLE    MD    7/4/2000 23:00
# 17322  Oakland             NaN       CYLINDER    CA    9/1/2000 21:35

# %%
ufo.loc[ufo.City=='Grand Rapids']
# Out:
#                City Colors Reported Shape Reported State              Time
# 1922   Grand Rapids             NaN           DISK    MI    1/1/1970 12:00
# 3633   Grand Rapids             NaN           CONE    MI    9/1/1977 20:00
# 3687   Grand Rapids             NaN           DISK    MI   1/12/1978 20:00
# 3688   Grand Rapids             NaN           DISK    MI   1/12/1978 20:00
# 3839   Grand Rapids             NaN       TRIANGLE    MI   7/10/1978 21:00
# 6506   Grand Rapids             NaN           DISK    MI   2/15/1991 22:00
# 6707   Grand Rapids             NaN          OTHER    MI  12/10/1991 21:30
# 7079   Grand Rapids             NaN          CIGAR    MI    6/15/1993 2:30
# 8062   Grand Rapids             NaN       TRIANGLE    MI    4/28/1995 9:30
# 8249   Grand Rapids             NaN           DISK    MI   6/15/1995 15:00
# 9562   Grand Rapids             NaN          LIGHT    MI    8/15/1996 2:30
# 9563   Grand Rapids             RED          LIGHT    MI    8/15/1996 2:30
# 10688  Grand Rapids       RED GREEN          LIGHT    MI    8/12/1997 1:00
# 10722  Grand Rapids             NaN        DIAMOND    MI   8/20/1997 18:00
# 11505  Grand Rapids             NaN            NaN    MN   5/10/1998 19:00
# 12461  Grand Rapids           GREEN       FIREBALL    MI   10/29/1998 3:30
# 12484  Grand Rapids             NaN       FIREBALL    MI    11/2/1998 3:45
# 13176  Grand Rapids             NaN       TRIANGLE    MI    3/12/1999 7:15
# 13178  Grand Rapids           GREEN      FORMATION    MI   3/12/1999 21:00
# 13306  Grand Rapids             NaN       TRIANGLE    MI   4/10/1999 20:00
# 13834  Grand Rapids             NaN          LIGHT    MI    7/2/1999 23:54
# 14258  Grand Rapids             RED          LIGHT    MI   8/17/1999 22:57
# 14438  Grand Rapids            BLUE          LIGHT    MI    9/4/1999 21:00
# 14552  Grand Rapids             NaN          FLASH    MI   9/11/1999 22:00
# 15176  Grand Rapids             RED          LIGHT    MI  11/16/1999 18:25
# 15476  Grand Rapids             NaN          OTHER    MI  12/10/1999 21:30
# 16319  Grand Rapids             NaN            NaN    MI   4/25/2000 21:25

# %%
ufo.loc[ufo.City=='Fort Wayne', 'State']
# Out:
# 3047     IN
# 4428     IN
# 5752     IN
# 5885     IN
# 7885     IN
# 7954     IN
# 7973     IN
# 8236     IN
# 12668    IN
# 13703    IN
# 14161    IN
# 15232    IN
# 15283    IN
# 16198    IN
# 16641    IN
# 17445    IN
# 17883    IN
# 18067    IN
# Name: State, dtype: object

# %%
ufo.iloc[:, 0:4]
# Out:
#                        City Colors Reported Shape Reported State
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
# [18241 rows x 4 columns]

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.iloc[0:3, : ]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo[['City', 'State']]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# ...                     ...   ...
# 18236            Grant Park    IL
# 18237           Spirit Lake    IA
# 18238           Eagle River    WI
# 18239           Eagle River    WI
# 18240                  Ybor    FL
#
# [18241 rows x 2 columns]

# %%
ufo[0:2]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.loc['Albania', 0].std()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
# ----> 1 drinks.loc['Albania', 0].std()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3615, in DataFrame._get_value(self, index, col, takeable)
#    3612     series = self._ixs(col, axis=1)
#    3613     return series._values[index]
# -> 3615 series = self._get_item_cache(col)
#    3616 engine = self.index._engine
#    3618 if not isinstance(self.index, MultiIndex):
#    3619     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3620     #  results if our categories are integers that dont match our codes
#    3621     # IntervalIndex: IntervalTree has no get_loc
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3931, in DataFrame._get_item_cache(self, item)
#    3926 res = cache.get(item)
#    3927 if res is None:
#    3928     # All places that call _get_item_cache have unique columns,
#    3929     #  pending resolution of GH#33047
# -> 3931     loc = self.columns.get_loc(item)
#    3932     res = self._ixs(loc, axis=1)
#    3934     cache[item] = res
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 0

# %%
drinks.iloc[1, 'beer_servings']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:769, in _LocationIndexer._validate_tuple_indexer(self, key)
#     768 try:
# --> 769     self._validate_key(k, i)
#     770 except ValueError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1378, in _iLocIndexer._validate_key(self, key, axis)
#    1377 else:
# -> 1378     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [82], in <cell line: 1>()
# ----> 1 drinks.iloc[1, 'beer_servings']
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1458, in _iLocIndexer._getitem_tuple(self, tup)
#    1456 def _getitem_tuple(self, tup: tuple):
# -> 1458     tup = self._validate_tuple_indexer(tup)
#    1459     with suppress(IndexingError):
#    1460         return self._getitem_lowerdim(tup)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:771, in _LocationIndexer._validate_tuple_indexer(self, key)
#     769         self._validate_key(k, i)
#     770     except ValueError as err:
# --> 771         raise ValueError(
#     772             "Location based indexing can only have "
#     773             f"[{self._valid_types}] types"
#     774         ) from err
#     775 return key
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %%
drinks.iloc['Albania': 'Andorra', 0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 drinks.iloc['Albania': 'Andorra', 0:2]
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1462, in _iLocIndexer._getitem_tuple(self, tup)
#    1459 with suppress(IndexingError):
#    1460     return self._getitem_lowerdim(tup)
# -> 1462 return self._getitem_tuple_same_dim(tup)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:827, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     824 if com.is_null_slice(key):
#     825     continue
# --> 827 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     828 # We should never have retval.ndim < self.ndim, as that should
#     829 #  be handled by the _getitem_lowerdim call above.
#     830 assert retval.ndim == self.ndim
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1497, in _iLocIndexer._getitem_axis(self, key, axis)
#    1491     raise IndexError(
#    1492         "DataFrame indexer is not allowed for .iloc\n"
#    1493         "Consider using .loc for automatic alignment."
#    1494     )
#    1496 if isinstance(key, slice):
# -> 1497     return self._get_slice_axis(key, axis=axis)
#    1499 if is_iterator(key):
#    1500     key = list(key)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1532, in _iLocIndexer._get_slice_axis(self, slice_obj, axis)
#    1529     return obj.copy(deep=False)
#    1531 labels = obj._get_axis(axis)
# -> 1532 labels._validate_positional_slice(slice_obj)
#    1533 return self.obj._slice(slice_obj, axis=axis)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:4005, in Index._validate_positional_slice(self, key)
#    3999 @final
#    4000 def _validate_positional_slice(self, key: slice) -> None:
#    4001     """
#    4002     For positional indexing, a slice must have either int or None
#    4003     for each of start, stop, and step.
#    4004     """
# -> 4005     self._validate_indexer("positional", key.start, "iloc")
#    4006     self._validate_indexer("positional", key.stop, "iloc")
#    4007     self._validate_indexer("positional", key.step, "iloc")
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6308, in Index._validate_indexer(self, form, key, kind)
#    6305 assert kind in ["getitem", "iloc"]
#    6307 if key is not None and not is_integer(key):
# -> 6308     raise self._invalid_indexer(form, key)
#
# TypeError: cannot do positional indexing on RangeIndex with these indexers [Albania] of type str

# %%
ufo.iloc[0:2, 0:2]
# Out:
#           City Colors Reported
# 0       Ithaca             NaN
# 1  Willingboro             NaN
